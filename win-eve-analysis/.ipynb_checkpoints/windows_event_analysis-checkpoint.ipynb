# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
events = pd.read_excel('win_event_log.xlsx')

# %%
events.head()
# Out:
#          Level       Date and Time            Source  Event ID Task Category  \
# 0  Information 2020-05-03 10:56:09             ESENT     916.0       General
# 1  Information 2020-05-03 10:50:21  HotKeyServiceUWP       0.0            -2
# 2  Information 2020-05-03 10:50:20  HotKeyServiceUWP       0.0            -2
# 3  Information 2020-05-03 10:47:46             ESENT     916.0       General
# 4  Information 2020-05-03 10:39:09             ESENT     916.0       General
#
#                                           Unnamed: 5
# 0  svchost (27956,G,98) The beta feature EseDiskF...
# 1  The description for Event ID 0 from source Hot...
# 2  The description for Event ID 0 from source Hot...
# 3  svchost (27272,G,98) The beta feature EseDiskF...
# 4  svchost (1560,G,98) The beta feature EseDiskFl...

# %%
events.describe()
# Out:
#            Event ID
# count  27666.000000
# mean    1270.406239
# std     2814.320906
# min        0.000000
# 25%        3.000000
# 50%      916.000000
# 75%     1001.000000
# max    26214.000000

# %%
events['Level'].value_counts().plot(kind='bar')

# %%
events.index(range)
# Out:
#                             Level             Date and Time  Source  \
# Error        02-May-20 6:33:16 PM                     ESENT   455.0
# Error        02-May-20 6:01:49 PM                     ESENT   455.0
# Information  02-May-20 6:00:43 PM  Microsoft-Windows-Defrag   258.0
# Information  02-May-20 5:56:54 PM            SecurityCenter    15.0
# Information  02-May-20 5:55:23 PM            SecurityCenter    15.0
#
#                      Event ID  \
# Error        Logging/Recovery
# Error        Logging/Recovery
# Information              None
# Information              None
# Information              None
#
#                                                  Task Category  \
# Error        svchost (11344,R,98) TILEREPOSITORYS-1-5-18: E...
# Error        svchost (6324,R,98) TILEREPOSITORYS-1-5-18: Er...
# Information  The storage optimizer successfully completed b...
# Information  Updated Windows Defender status successfully t...
# ...

# %%
events['Event ID']
# Out:
# Error          Logging/Recovery
# Error          Logging/Recovery
# Information                None
# Information                None
# Information                None
#                      ...
# Error                      None
# Information                None
# Information                None
# Information                None
# Information                None
# Name: Event ID, Length: 20251, dtype: object

# %%
events.reset_index()
# Out:
#              index                 Level  \
# 0            Error  02-May-20 6:33:16 PM
# 1            Error  02-May-20 6:01:49 PM
# 2      Information  02-May-20 6:00:43 PM
# 3      Information  02-May-20 5:56:54 PM
# 4      Information  02-May-20 5:55:23 PM
# ...            ...                   ...
# 20246        Error  22-Aug-19 6:02:00 PM
# 20247  Information  22-Aug-19 6:01:34 PM
# 20248  Information  22-Aug-19 6:01:07 PM
# 20249  Information  22-Aug-19 6:01:06 PM
# 20250  Information  22-Aug-19 6:01:34 PM
#
#                                  Date and Time  Source          Event ID  \
# 0                                        ESENT   455.0  Logging/Recovery
# 1                                        ESENT   455.0  Logging/Recovery
# 2                     Microsoft-Windows-Defrag   258.0              None
# 3                               SecurityCenter    15.0              None
# 4                               SecurityCenter    15.0              None
# ...

# %%
events.Source
# Out:
# Error           455.0
# Error           455.0
# Information     258.0
# Information      15.0
# Information      15.0
#                 ...
# Error           256.0
# Information    1531.0
# Information    5617.0
# Information    5615.0
# Information    4625.0
# Name: Source, Length: 20251, dtype: float64
